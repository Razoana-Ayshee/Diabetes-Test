# %%
#Group_member1:
#Name:Ishrat Jaben Bushra
#ID:2018-1-60-099
#Group_member2:
#Name:Razoana Ayshee
#ID:2018-1-60-229
#dataset_link:-https://www.kaggle.com/uciml/pima-indians-diabetes-database
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("diabetess.csv")
data

# %%
x=data[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]

# %%
y=data['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)
#x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10) 
#"random_state=10" for the smaple will be same all the time

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 130            4      173             70             14      168  29.7
# 250            9      106             52              0        0  31.2
# 256            3      111             56             39        0  30.1
# 537            0       57             60              0        0  21.7
# 304            3      150             76              0        0  21.0
# ..           ...      ...            ...            ...      ...   ...
# 633            1      128             82             17      183  27.5
# 268            0      102             52              0        0  25.1
# 542           10       90             85             32        0  34.9
# 666            4      145             82             18        0  32.5
# 474            4      114             64              0        0  28.9
#
#      DiabetesPedigreeFunction  Age
# 130                     0.361   33
# 250                     0.380   42
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 642            6      147             80              0        0  29.5
# 162            0      114             80             34      285  44.2
# 147            2      106             64             35      119  30.5
# 735            4       95             60             32        0  35.4
# 17             7      107             74              0        0  29.6
# ..           ...      ...            ...            ...      ...   ...
# 180            6       87             80              0        0  23.2
# 465            0      124             56             13      105  21.8
# 719            5       97             76             27        0  35.6
# 649            0      107             60             25        0  26.4
# 551            3       84             68             30      106  31.9
#
#      DiabetesPedigreeFunction  Age
# 642                     0.178   50
# 162                     0.167   27
# ...

# %%
y_train
# Out:
# 130    1
# 250    0
# 256    0
# 537    0
# 304    0
#       ..
# 633    0
# 268    0
# 542    1
# 666    1
# 474    0
# Name: Outcome, Length: 614, dtype: int64

# %%
 y_test
# Out:
# 642    1
# 162    0
# 147    0
# 735    0
# 17     1
#       ..
# 180    0
# 465    0
# 719    1
# 649    0
# 551    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from keras.models import Sequential
from keras.layers import Dense
neu_net = Sequential()
neu_net.add(Dense(8,activation='relu',input_shape=(8, )))
neu_net.add(Dense(8,activation='relu'))#relu works better for hidden layers
neu_net.add(Dense(8,activation='relu'))
neu_net.add(Dense(8,activation='relu'))
neu_net.add(Dense(8,activation='relu'))
neu_net.add(Dense(8,activation='relu'))
neu_net.add(Dense(1,activation='sigmoid'))#our project is binary classification so used sigmoid

# %%
#neu_net.summary()

# %%
neu_net.compile(optimizer='sgd',
              loss='mean_squared_error',
             metrics=['accuracy'])

# %%
neu_net.fit(x_train, y_train, epochs=1200)
# Out:
# Epoch 1/1200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2565 - accuracy: 0.6678
# Epoch 2/1200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2432 - accuracy: 0.6678
# Epoch 3/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.6678
# Epoch 4/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.6678
# Epoch 5/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2399 - accuracy: 0.6678
# Epoch 6/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.6678
# Epoch 7/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.6678
# Epoch 8/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.6678
# Epoch 9/1200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.6678
# Epoch 10/1200
# ...

# %%
y_pred =neu_net.predict(x_test)
print(y_pred)
# Out:
# [[0.29210564]
#  [0.18005162]
#  [0.15666458]
#  [0.15210369]
#  [0.1596134 ]
#  [0.03157187]
#  [0.5926759 ]
#  [0.19179967]
#  [0.2890054 ]
#  [0.1398032 ]
#  [0.26283   ]
#  [0.02630156]
#  [0.85192686]
#  [0.70455027]
#  [0.47815374]
#  [0.30780774]
#  [0.23918244]
#  [0.50194824]
#  [0.7920667 ]
#  [0.46652752]
#  [0.34218156]
#  [0.7288258 ]
#  [0.77706456]
#  [0.26069158]
#  [0.55148685]
#  [0.3203419 ]
#  [0.15110493]
#  [0.5184771 ]
#  [0.14368102]
#  [0.10563803]
#  [0.39758646]
#  [0.72580636]
#  [0.25957483]
#  [0.14900231]
#  [0.15029138]
#  [0.09748435]
#  [0.5157678 ]
#  [0.50044674]
#  [0.30367696]
#  [0.08567995]
#  [0.14523008]
#  [0.10064328]
#  [0.06765223]
#  [0.7408332 ]
#  [0.08449659]
#  [0.52493376]
#  [0.16630307]
#  [0.24774334]
#  [0.02099922]
#  [0.48320392]
#  [0.14093763]
#  [0.06852859]
#  [0.6284532 ]
#  [0.04348323]
#  [0.05403149]
#  [0.09652072]
#  [0.34166795]
#  [0.4816691 ]
#  [0.13722205]
#  [0.17648664]
#  [0.84119505]
#  [0.07661042]
# ...

# %%
test_loss, test_acc = (neu_net.evaluate(x_test, y_test, verbose=2))
test_acc=test_acc*100
test_acc
# Out:
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 5/5 - 0s - loss: 0.1901 - accuracy: 0.7338
# 73.3766257762909

# %%
import numpy as np 
x1=float(input('Enter feature 1 : '))
x2=float(input('Enter feature 2 : '))
x3=float(input('Enter feature 3 : '))
x4=float(input('Enter feature 4 : '))
x5=float(input('Enter feature 5 : '))
x6=float(input('Enter feature 6 : '))
x7=float(input('Enter feature 7 : '))
x8=float(input('Enter feature 8 : '))




user_prediction=neu_net.predict([[x1,x2,x3,x4,x5,x6,x7,x8]])


prediction=np.asscalar(np.array(user_prediction))
#for converting from array to scalar
print('prediction =',prediction)
